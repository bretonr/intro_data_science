# %%
## Import required Python modules
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy, scipy.stats
import io
import base64
#from IPython.core.display import display
from IPython.display import display, HTML, Image
from urllib.request import urlopen

try:
    import astropy as apy
    import astropy.table
    _apy = True
    #print('Loaded astropy')
except:
    _apy = False
    #print('Could not load astropy')

## Customising the font size of figures
plt.rcParams.update({'font.size': 14})

## Customising the look of the notebook
display(HTML("<style>.container { width:95% !important; }</style>"))
## This custom file is adapted from https://github.com/lmarti/jupyter_custom/blob/master/custom.include
HTML('custom.css')
#HTML(urlopen('https://raw.githubusercontent.com/bretonr/intro_data_science/master/custom.css').read().decode('utf-8'))
# Out:
# <style>.container { width:95% !important; }</style>
# <link href="https://fonts.googleapis.com/css?family=Fira+Sans:300,300i,600,600i" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Inconsolata" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Titillium+Web:400,400i,700,700i" rel="stylesheet">
#
#
# <style>
#
# .container {
#     max-width:1000px !important;
# }
#
# .text_cell_render p {
# font-style: regular;
# font-family: 'Fira Sans', sans-serif;
# display: block;
# text-align: justify;
# }
# /*font-weight: 200;*/
# /*text-align: left;
# line-height: 100%;
# display: block;
# }*/
# a {
# color:#377bb5;
# }
# .text_cell_render h1 {
# /*font-size: 24pt;*/
# font-family: 'Titillium Web', sans-serif;
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#4a4a4a;
# }
# .text_cell_render h2 {
# /*font-size: 21pt;*/
#     font-family: 'Titillium Web', sans-serif;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# ...

# %%
## Adding a button to hide the Python source code
HTML('''<script>
code_show=true;
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-8" align="center">
#             <h1>PHYS 10791: Introduction to Data Science</h1>
#             <!--<h3>2019-2020 Academic Year</h3><br>-->
#         </div>
#         <div class="col-md-3">
#             <img align='center' style="border-width:0" src="images/UoM_logo.png"/>
#         </div>
#     </div>
# </div>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-2" align="right">
#             <b>Course instructors:&nbsp;&nbsp;</b>
#         </div>
#         <div class="col-md-9" align="left">
#             <a href="http://www.renebreton.org">Prof. Rene Breton</a> - Twitter <a href="https://twitter.com/BretonRene">@BretonRene</a><br>
#             <a href="http://www.hep.manchester.ac.uk/u/gersabec">Dr. Marco Gersabeck</a> - Twitter <a href="https://twitter.com/MarcoGersabeck">@MarcoGersabeck</a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# # Weekly plan 2
#
# Week 2 covers Chapter 2 of the course syllabus.

# %% [markdown]
# ## Instructions for the week
#
# _Before the lecture_
# - Have a quick look at the summary sheet.
# - Watch the videos for a walk-through of the material.
# - Read through the lecture notes.
# - Look at the problem sheet.
#
# _At the lecture_
# - Ask questions.
#
# _After the lecture_
# - Try the Blackboard quiz and submit an attempt before the deadline.

# %% [markdown]
# ## Continuous assessment
#
# 1. Online Blackboard weekly quiz

# %% [markdown]
# # Chapter 2
#
# ## Topics
#
# **2.1 Probabilities and random variables**
# - 2.1.1 Axioms of probability
# - 2.1.2 Bayes' theorem
# - **Case study**: The mesmerising effect of Bayes' theorem
#
# **2.2 Probability distributions**
# - 2.2.1 General probability distributions
#     - Discrete probability distribution
#     - Continuous probability distribution
# - 2.2.2 Some important probability distributions
#     - Binomial distribution
#     - Poisson distribution
#     - Gaussian/Normal distribution
# - 2.2.3 Gaussian distribution as limit of Poisson and Binomial distributions
# - ~~2.2.4 Other probability distributions~~ *(non-examinable content)*
#     - ~~Uniform, $\chi^2$, Student's t, Fisher's F~~
#     - ~~Multivariate Gaussian~~

# %% [markdown]
# ## Intended learning outcomes
#
# 1. Use the key properties derived from the axioms of probability
# 2. Understand and apply Bayes' theorem to perform probability inference
# 3. Distinguish the key probability distributions and solve statistical problems

# %% [markdown]
# ## Further Reading Material
#
# - **Cowan**: Chapter 1 - *Axioms of probability and Bayes theorem*
# - **Barlow**: Chapter 7.1 - *Axioms of probability and Bayes theorem*
# - **Barlow**: Chapter 3 - *Introduction to some key probability distributions*
# - **Cowan**: Chapter 2 - *Introduction to some key probability distributions*
# - Wikipedia page on [Bayes' theorem](https://en.wikipedia.org/wiki/Bayes%27_theorem)

# %% [markdown]
# <div class="well" align="center">
#     <div class="container-fluid">
#         <div class="row">
#             <div class="col-md-3" align="center">
#                 <img align="center" alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" width="60%">
#             </div>
#             <div class="col-md-8">
#             This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>).
#             </div>
#         </div>
#     </div>
#     <br>
#     <br>
#     <i>Note: The content of this Jupyter Notebook is provided for educational purposes only.</i>
# </div>

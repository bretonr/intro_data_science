# %%
from IPython.display import HTML, Image, display
HTML('custom.css')
# Out:
# <link href="https://fonts.googleapis.com/css?family=Fira+Sans:300,300i,600,600i" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Inconsolata" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Titillium+Web:400,400i,700,700i" rel="stylesheet">
#
#
# <style>
#
# .text_cell_render p {
# font-style: regular;
# font-family: 'Fira Sans', sans-serif;
# display: block;
# text-align: justify;
# }
# /*font-weight: 200;*/
# /*text-align: left;
# line-height: 100%;
# display: block;
# }*/
#
# .text_cell_render h1 {
# /*font-size: 24pt;*/
# font-family: 'Titillium Web', sans-serif;
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#4a4a4a;
# }
# .text_cell_render h2 {
# /*font-size: 21pt;*/
#     font-family: 'Titillium Web', sans-serif;
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
# .text_cell_render h3 {
#     font-family: 'Titillium Web', sans-serif;
# /*font-size: 19pt;*/
# margin-bottom: 0.1em;
# ...

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-3">
#             <img align='center' style="border-width:0" src="images/UoM_logo.png"/>
#         </div>
#         <div class="col-md-8" align='center'>
#             <h1>PHYS 10792: Introduction to Data Science</h1>
#             <h3>2018-2019 Academic Year</h3>
#         </div>
#     </div>
# </div>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-5" align='right'><b>Course instructors:&nbsp;&nbsp;</b></div>
#         <div class="col-md-6" align='left'>
#             Rene Breton - Twitter @BretonRene<br>
#             Marco Gersabeck - Twitter @MarcoGersabeck
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-3">
#             <img align='center' style="border-width:0" src="images/UoM_logo.png"/>
#         </div>
#         <div class="col-md-8" align='center' vertical-align='top'>
#             <h1>PHYS 10792: Introduction to Data Science</h1>
#             <h3>2018-2019 Academic Year</h3><br>
#             <div class="row" align='left'>
#                 <div class="col-md-3" align='right'><b>Course instructors:&nbsp;&nbsp;</b></div>
#                 <div class="col-md-6" align='left'>
#                 Rene Breton - Twitter @BretonRene<br>
#                 Marco Gersabeck - Twitter @MarcoGersabeck
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# &nbsp;&nbsp;

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-5" align='right'><b>Course instructors:</b></div>
#         <div class="col-md-1" align='left'>&nbsp;</div>
#         <div class="col-md-4" align='left'>
#             Rene Breton - Twitter @BretonRene<br>
#             Marco Gersabeck - Twitter @MarcoGersabeck
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row row-no-gutters">
#         <div class="col-md-5" align='right'><b>Course instructors:</b></div>
#         <div class="col-md-6" align='left'>
#             Rene Breton - Twitter @BretonRene<br>
#             Marco Gersabeck - Twitter @MarcoGersabeck
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-1" align="right">1</div>
#         <div class="col-md-1" align="right">2</div>
#         <div class="col-md-1" align="right">3</div>
#         <div class="col-md-1" align="right">4</div>
#         <div class="col-md-1" align="right">5</div>
#         <div class="col-md-1" align="right">6</div>
#         <div class="col-md-1" align="right">7</div>
#         <div class="col-md-1" align="right">8</div>
#         <div class="col-md-1" align="right">9</div>
#         <div class="col-md-1" align="right">10</div>
#         <div class="col-md-1" align="right">11</div>
#         <div class="col-md-1" align="right">12</div>
#     </div>
# </div>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-3">
#             blah
#         </div>
#         <div class="col-md-8" align='right'>
#             stu
#         </div>
#     </div>
# </div>

# %% [markdown]
# <table class="bordered">
#   <tr>
#   <th>Firstname</th>
#   <th>Lastname</th>
#   <th>Savings</th>
#   </tr>
#   <tr>
#   <td>Peter</td>
#   <td>Griffin</td>
#   <td>100</td>
#   </tr>
#   <tr>
#   <td>Lois</td>
#   <td>Griffin</td>
#   <td>150</td>
#   </tr>
#   <tr>
#   <td>Joe</td>
#   <td>Swanson</td>
#   <td>300</td>
#   </tr>
#   <tr>
#   <td>Cleveland</td>
#   <td>Brown</td>
#   <td>250</td>
# </tr>
# </table>

# %% [markdown]
# <div class="row">
#     <div class="col-md-3">
#         <img align='center' style="border-width:0" src="images/UoM_logo.png"/>
#     </div>
#     <div class="col-md-9" align='center'>
#         <h1>PHYS 10792: Introduction to Data Science</h1>
#         <h3>2018-2019 Academic Year</h3>
#         <br>
#         <br>
#         <div class="row">
#             <div class="col-md-1" align='left'>&nbsp;</div>
#             <div class="col-md-3" align='right'><b>Course instructors:&nbsp;&nbsp;</b></div>
#             <div class="col-md-8" align='left'>
#                 Rene Breton - Twitter @BretonRene<br>
#                 Marco Gersabeck - Twitter @MarcoGersabeck
#             </div>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <div class="row">
#   <div class="col-md-8">
#     .col-8
#     <div class="row">
#       <div class="col-md-6">.col-6</div>
#       <div class="col-md-6">.col-6</div>
#     </div>
#   </div>
#   <div class="col-md-4">.col-4</div>
# </div>

# %% [markdown]
# <div class="well">
#     <div class="row">
#         <div class="col-md-3" align="center">
#             <img align="center" alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png"/>
#         </div>
#         <div class="col">
#         This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>).
#         </div>
#     </div>
# </div>

# %%
## Import required Python modules
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy, scipy.stats
import io
import base64
#from IPython.core.display import display
from IPython.display import display, HTML, Image
from urllib.request import urlopen

try:
    import astropy as apy
    import astropy.table
    _apy = True
    #print('Loaded astropy')
except:
    _apy = False
    #print('Could not load astropy')

## Customising the font size of figures
plt.rcParams.update({'font.size': 14})

## Customising the look of the notebook
display(HTML("<style>.container { width:95% !important; }</style>"))
## This custom file is adapted from https://github.com/lmarti/jupyter_custom/blob/master/custom.include
HTML('custom.css')
#HTML(urlopen('https://raw.githubusercontent.com/bretonr/intro_data_science/master/custom.css').read().decode('utf-8'))
# Out:
# <style>.container { width:95% !important; }</style>
# <link href="https://fonts.googleapis.com/css?family=Fira+Sans:300,300i,600,600i" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Inconsolata" rel="stylesheet">
# <link href="https://fonts.googleapis.com/css?family=Titillium+Web:400,400i,700,700i" rel="stylesheet">
#
#
# <style>
#
# .text_cell_render p {
# font-style: regular;
# font-family: 'Fira Sans', sans-serif;
# display: block;
# text-align: justify;
# }
# /*font-weight: 200;*/
# /*text-align: left;
# line-height: 100%;
# display: block;
# }*/
# a {
# color:#377bb5;
# }
# .text_cell_render h1 {
# /*font-size: 24pt;*/
# font-family: 'Titillium Web', sans-serif;
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#4a4a4a;
# }
# .text_cell_render h2 {
# /*font-size: 21pt;*/
#     font-family: 'Titillium Web', sans-serif;
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
# .text_cell_render h3 {
#     font-family: 'Titillium Web', sans-serif;
# /*font-size: 19pt;*/
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
# .text_cell_render h4 {
#     font-family: 'Titillium Web', sans-serif;
# /*font-size: 17pt;*/
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
# .text_cell_render h5 {
#     font-family: 'Titillium Web', sans-serif;
# /*font-size: 15pt;*/
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
# div.text_cell_render{
# font-style: regular;
# font-family: 'Fira Sans', sans-serif;
# line-height: 120%;
# font-size: 100%;
# font-weight: 400;
# text-align: justify;
# margin-left:0em;
# margin-right:0em;
# }
# code {
# font-family: 'Inconsolata', monospace;
# }
# pre {
# font-family: 'Inconsolata', monospace;
# }
#
# div.example {
#     font-family: 'Titillium Web', sans-serif;
# /*font-size: 15pt;*/
# font-weight: bold;
# font-variant: small-caps;
# text-decoration: underline;
# margin-bottom: 0.1em;
# margin-top: 0.3em;
# color:#595959;
# }
#
# div.queue {
# font-size: x-large;
# font-variant: small-caps;
# font-family: 'Titillium Web', sans-serif;
# font-weight: bold;
# /*margin-bottom: 0.1em;*/
# /*margin-top: 0.5em;*/
# margin: 10px;
# padding: 10px;
# color:#cc0000;
# border-style: solid none solid none;
# border-width: 2px;
# border-color:#cc0000;
# border-spacing: 10px;
# }
#
# .reveal h1 {
# font-family: 'Titillium Web', sans-serif;
# /*font-size: 24pt;*/
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#4a4a4a;
# }
# .reveal h2 {
# font-family: 'Titillium Web', sans-serif;
# /*font-size: 24pt;*/
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#595959;
# }
# .reveal h3 {
# font-family: 'Titillium Web', sans-serif;
# /*font-size: 24pt;*/
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#595959;
# }
# .reveal h4 {
# font-family: 'Titillium Web', sans-serif;
# font-weight: bold;
# margin-bottom: 0.1em;
# margin-top: 0.5em;
# color:#595959;
# }
# .reveal div.text_cell_render{
# line-height: 120%;
# font-size: 74%;
# font-weight: 400;
# text-align: justify;
# margin-left:0em;
# margin-right:0em;
# }
# .reveal .code_cell {
#     font-size: 92%;
# }
# .reveal code {
# font-family: 'Inconsolata', monospace;
# }
# .reveal pre {
# font-family: 'Inconsolata', monospace;
# }
#
# .CodeMirror{
# font-family: "Inconsolata", monospace;
# }
#
# </style>

# %%
## Adding a button to hide the Python source code
HTML('''<script>
code_show=true;
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the Python code."></form>

# %% [markdown]
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-8" align="center">
#             <h1>PHYS 10791: Introduction to Data Science</h1>
#             <!--<h3>2019-2020 Academic Year</h3><br>-->
#         </div>
#         <div class="col-md-3">
#             <img align='center' style="border-width:0" src="images/UoM_logo.png"/>
#         </div>
#     </div>
# </div>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-md-2" align="right">
#             <b>Course instructors:&nbsp;&nbsp;</b>
#         </div>
#         <div class="col-md-9" align="left">
#             <a href="http://www.renebreton.org">Prof. Rene Breton</a> - Twitter <a href="https://twitter.com/BretonRene">@BretonRene</a><br>
#             <a href="http://www.hep.manchester.ac.uk/u/gersabec">Dr. Marco Gersabeck</a> - Twitter <a href="https://twitter.com/MarcoGersabeck">@MarcoGersabeck</a>
#         </div>
#     </div>
# </div>

# %% [markdown]
# # Chapter 4 - Summary

# %% [markdown]
# ## 4.1 Bayesian inference and likelihood function

# %% [markdown]
# ### 4.1.1 Recap and likelihood function

# %% [markdown]
# Bayes' theorem:
#
# \begin{eqnarray}
#   P(a \mid x) &=& \frac{I(a) \mathcal{L}(x \mid a)}{E(x)} \\
#          &=& \frac{I(a) \mathcal{L}(x \mid a)}{\sum_i \mathcal{L}(x \mid a_i) I(a_i)} \\
#          &=& \frac{I(a) \prod \mathcal{L}(x_i \mid a)}{E(x)}
# \end{eqnarray}
#
# with:
#
# - $P$: the posterior probability
# - $I$: the prior probability
# - $\mathcal{L}$: the likelihood probability
# - $E$: the evidence
# - $x = \{x_1, x_2, ..., x_N\}$: the data
# - $a$: the parameter (or model)

# %% [markdown]
# ### 4.1.2 Maximum a posteriori and maximum likelihood

# %% [markdown]
# #### Maximum a posteriori (MAP):
#
# \begin{eqnarray}
#   \widehat{a}_{\rm MAP} &=& \arg \max_{\substack a} P(a \mid x) &\equiv& \left[ \frac{\partial P(a \mid x)}{\partial a} \right]_{a = \widehat{a}} = 0\\
#               &=& \arg \max_{\substack a} \ln P(a \mid x) &\equiv& \left[ \frac{\partial \ln P(a \mid x)}{\partial a} \right]_{a = \widehat{a}} = 0 \,.
# \end{eqnarray}
#
# ##### Recall
# The value of $E(x)$ is irrelevant as it is independent of $a$.

# %% [markdown]
# #### Maximum likelihood estimation (MLE)
#
# \begin{eqnarray}
#   \widehat{a}_{\rm MLE} &=& \arg \max_{\substack a} \mathcal{L}(a \mid x) &\equiv& \left[ \frac{\partial \mathcal{L}(a \mid x)}{\partial a} \right]_{a = \widehat{a}} = 0\\
#               &=& \arg \max_{\substack a} \ln \mathcal{L}(a \mid x) &\equiv& \left[ \frac{\partial \ln \mathcal{L}(a \mid x)}{\partial a} \right]_{a = \widehat{a}} = 0 \,.
# \end{eqnarray}
#
# ##### Recall
# The MAP reduces to the MLE when the priors are independent of the parameter, $a$.

# %% [markdown]
# ## 4.2 Maximum likelihood as an estimator

# %% [markdown]
# The MLE can be thought of as a good estimator in most cases:
# 1. Generally (though not strictly always) consistent
# 2. Generally biased, but this disappears in the limit of large $N$ for any consistent estimator
# 3. Generally invariant
# 4. Generally efficient

# %% [markdown]
# ### 4.2.1 Maximum likelihood invariance

# %% [markdown]
# Through the chain rule we can demonstrate that the MLE is invariant under parameter transformations. Hence: $\widehat{f(a)} = f(\widehat{a})$.

# %% [markdown]
# ### 4.2.2 Efficiency of the maximum likelihood

# %% [markdown]
# The Rao-Cramér-Frechet (RCF) inequality provides a minimum bound for the variance of the maximum likelihood. When the maximum likelihood is unbiased (or the bias can be neglected), we obtain the minimum variance bound (MVB):
#
# \begin{equation}
#   V(\widehat{a})_{\rm MVB} \ge \frac{1}{\left< -\frac{\partial^2 \ln \mathcal{L}}{\partial a^2} \right>} \,.
# \end{equation}

# %% [markdown]
# ### 4.2.3 Variance on maximum likelihood estimators

# %% [markdown]
# The MVB provides a useful way to determine the variance on the MLE:
#
# \begin{equation}
#   V(\widehat{a}) = \sigma^2_\widehat{a} = \left[ \left( -\frac{\partial^2 \ln \mathcal{L}}{\partial a^2} \right)^{-1} \right]_\widehat{a} \,.
# \end{equation}
#
# In the case of multiple parameters, this becomes:
#
# \begin{equation}
#   V(\widehat{a}_{ij}) = \left[ -\frac{\partial^2 \ln \mathcal{L}}{\partial a_i \partial a_j} \right]^{-1}_\widehat{a} \,.
# \end{equation}
#
# ##### Recall
# Writing all combinations of the above equation as a matrix is called the **Fisher information matrix**, and its (matrix) inverse provides the covariance matrix of the estimated parameters.
#
# If the MLE is Taylor-expanded to first-order around the maximum, the Fisher information gives the uncertainty on the parameters. In which case, the log-likelihood would be shaped as a parabola.

# %% [markdown]
# <div class="well" align="center">
#     <div class="container-fluid">
#         <div class="row">
#             <div class="col-md-3" align="center">
#                 <img align="center" alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" width="60%">
#             </div>
#             <div class="col-md-8">
#             This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>).
#             </div>
#         </div>
#     </div>
#     <br>
#     <br>
#     <i>Note: The content of this Jupyter Notebook is provided for educational purposes only.</i>
# </div>
